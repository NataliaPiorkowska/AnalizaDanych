# %% [markdown]
# # test

# %%
10 + 10
# Out:
# 20

# %%
import csv
file = open("TRAN_1754_XTAB_20211102214606.csv")
csvreaderss = csv.reader(file)
rows = []
for row in csvreaderss:
        rows.append(row)
rows
# Out:
# [['Kod;Nazwa;ofiary śmiertelne;;;;;;;;;;;;;;;;;;;;;'],
#  [';;1999;2000;2001;2002;2003;2004;2005;2006;2007;2008;2009;2010;2011;2012;2013;2014;2015;2016;2017;2018;2019;2020'],
#  [';;[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba];[osoba]'],
#  ['0000000;POLSKA;6 730;6 294;5 536;5 827;5 640;5 712;5 444;5 243;5 583;5 437;4 572;3 907;4 195;3 577;3 357;3 202;2 938;3 026;2 831;2 862;2 909;2 491'],
#  ['0200000;DOLNOŚLĄSKIE;466;454;377;393;374;371;364;344;359;363;294;241;259;239;223;242;185;226;219;203;215;165'],
#  ['0201000;Powiat bolesławiecki;-;-;-;-;-;-;-;-;-;-;-;-;10;8;11;11;5;11;11;7;19;10'],
#  ['0202000;Powiat dzierżoniowski;-;-;-;-;-;-;-;-;-;-;-;-;20;8;5;7;7;9;10;7;7;7'],
#  ['0203000;Powiat głogowski;-;-;-;-;-;-;-;-;-;-;-;-;4;7;4;6;0;9;5;5;3;4'],
#  ['0204000;Powiat górowski;-;-;-;-;-;-;-;-;-;-;-;-;2;4;5;1;2;3;5;0;0;3'],
# ...
